# %%
#대학평가(kaggle에서 수집한 데이터를 가공하여 실습)
import pandas as pd
df = pd.read_csv("c:/data/school/data.csv")
df.head()
# Out:
#    teaching  international  research  citations  income  num_students  \
# 0      12.4           95.6      10.6       13.3    33.3          5226
# 1      29.9           90.1      20.1       65.3    33.9          2473
# 2      24.7           82.6      18.9       43.5    28.4          2473
# 3      61.3           98.6      67.5       94.6    65.4          9666
# 4      62.4           98.8      57.0       95.0    49.8          9666
#
#    student_staff_ratio  international_students  total_score  Label
# 0                 14.1                    0.82         59.8      0
# 1                 15.6                    0.63         59.8      0
# 2                 15.6                    0.63         59.8      0
# 3                 10.5                    0.54         76.1      1
# 4                 10.5                    0.54         73.0      1

# %%
train_cols = df.columns[0:8]
print(train_cols)
X = df[train_cols] # 독립변수
y = df["Label"] # 종속변수
# Out:
# Index(['teaching', 'international', 'research', 'citations', 'income',
#        'num_students', 'student_staff_ratio', 'international_students'],
#       dtype='object')

# %%
df["Label"].value_counts()
# Out:
# 0    2158
# 1     445
# Name: Label, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
#한글 처리를 위해 폰트 설정
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import seaborn as sns
colors = ["yellow", "red"]
sns.countplot('Label', data=df, palette=colors)
plt.title('분류\n (0: bad, 1: good)', fontsize=14)
#불균형 데이터셋
# Out:
# c:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, '분류\n (0: bad, 1: good)')

# %%
#언더샘플링
from imblearn.under_sampling import RandomUnderSampler
X_sample, y_sample = RandomUnderSampler(random_state=0).fit_resample(X, y)
X_samp = pd.DataFrame(data=X_sample,columns=train_cols )
y_samp = pd.DataFrame(data=y_sample,columns=['Label'])
df_samp=pd.concat([X_samp,y_samp],axis=1)
df_samp["Label"].value_counts()
# Out:
# 0    445
# 1    445
# Name: Label, dtype: int64

# %%
X=df_samp[train_cols]
y=df_samp["Label"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=10)

# %% [markdown]
# ##### 로지스틱회귀분석

# %%
#로지스틱 회귀분석
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression(random_state=10,max_iter=1000)
logit.fit(X_train, y_train)
print("학습용:",logit.score(X_train, y_train))
print("검증용:",logit.score(X_test, y_test))
# Out:
# 학습용: 0.8862359550561798
# 검증용: 0.8651685393258427

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaler.fit(X_train)
X_train_scaled = pd.DataFrame(scaler.transform(X_train))
X_test_scaled = pd.DataFrame(scaler.transform(X_test))

# %%
#다양한 알고리즘별 정확도를 저장할 리스트
result_tr=[]
result_te=[]

# %%
logit = LogisticRegression(random_state=10)
logit.fit(X_train_scaled, y_train)
score_tr=logit.score(X_train_scaled, y_train)
score_te=logit.score(X_test_scaled, y_test)
print("학습용:",score_tr)
print("검증용:",score_te)
result_tr.append(score_tr)
result_te.append(score_te)
# Out:
# 학습용: 0.9887640449438202
# 검증용: 0.9943820224719101

# %% [markdown]
# ##### 결정나무모형

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier(random_state=10)
tree.fit(X_train_scaled, y_train)
print("학습용:",tree.score(X_train_scaled, y_train))
print("검증용:",tree.score(X_test_scaled, y_test))
# Out:
# 학습용: 1.0
# 검증용: 0.9719101123595506

# %%
# max_depth 가지치기
tree = DecisionTreeClassifier(max_depth=4, random_state=10)
tree.fit(X_train_scaled, y_train)
score_tr=tree.score(X_train_scaled, y_train)
score_te=tree.score(X_test_scaled, y_test)
print("학습용:",score_tr)
print("검증용:",score_te)
# Out:
# 학습용: 0.9789325842696629
# 검증용: 0.9775280898876404

# %%
result_tr.append(score_tr)
result_te.append(score_te)

# %%
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image
dot_data = export_graphviz(tree, out_file=None,
feature_names=train_cols, class_names=["0","1"], filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
#0~1 사이의 값(0 전혀 사용되지 않음 ~ 1 완벽하게 타겟 클래스 예측)
import numpy as np
def plot_tree(model):
    n_features = X.shape[1]
    plt.rcParams["figure.figsize"]=(16,9)
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), train_cols)
    plt.xlabel("특성 중요도")
    plt.ylabel("특성")
    plt.ylim(-1, n_features)
plot_tree(tree)

# %% [markdown]
# ##### 랜덤포레스트

# %%
from sklearn.ensemble import RandomForestClassifier
#100개의 트리로 구성된 랜덤 포레스트
forest = RandomForestClassifier(n_estimators=100, random_state=10)
forest.fit(X_train_scaled, y_train)
score_tr=forest.score(X_train_scaled, y_train)
score_te=forest.score(X_test_scaled, y_test)
print("학습용:",score_tr)
print("검증용:",score_te)
# Out:
# 학습용: 1.0
# 검증용: 0.9943820224719101

# %%
result_tr.append(score_tr)
result_te.append(score_te)

# %%
plot_tree(forest)

# %% [markdown]
# ##### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np
train_rate = []
test_rate = []
# 새로운 데이터 포인트에 가장 가까운 k개의 이웃을 찾는다.
# k의 값에 따라 결과가 달라지므로 어떤 값이 최적인지 찾아내는 것이 필요함
# 1 에서 10 까지 n_neighbors 를 적용
neighbors = range(1, 11)
for n in neighbors:
    # 모델 생성
    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(X_train_scaled, y_train)
    # 학습용 데이터셋의 정확도
    train_rate.append(knn.score(X_train_scaled, y_train))
    # 검증용 데이터셋의 정확도
    test_rate.append(knn.score(X_test_scaled, y_test))
    
test_arr=np.array(test_rate) #검증용 데이터셋의 정확도
max_rate=np.max(test_arr) #가장 좋은 정확도
idx=np.where(test_arr == max_rate)[0][0] #가장 성능이 좋은 인덱스
print("최적의 k:",neighbors[idx])
print("최고 정확도:",test_rate[idx])
# Out:
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 최적의 k: 5
# 최고 정확도: 0.9887640449438202
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
plt.rcParams["font.size"]=15
plt.plot(neighbors, train_rate, label="학습용 데이터셋")
plt.plot(neighbors, test_rate, label="검증용 데이터셋")
plt.ylabel("정확도")
plt.xlabel("이웃의 수")
plt.legend()
#학습용 데이터셋의 경우 이웃이 1개일 때 100% 예측
#이웃의 수가 늘어나면 학습용 데이터셋의 경우 모델이 단순해지고 정확도는 줄어든다.

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_scaled, y_train)
score_tr=knn.score(X_train_scaled, y_train)
score_te=knn.score(X_test_scaled, y_test)
print("학습용:",score_tr)
print("검증용:",score_te)
# Out:
# 학습용: 0.9803370786516854
# 검증용: 0.9719101123595506
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
result_tr.append(score_tr)
result_te.append(score_te)

# %% [markdown]
# ##### 인공신경망

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(random_state=10)
mlp.fit(X_train_scaled, y_train)
print("학습용:",mlp.score(X_train_scaled, y_train))
print("검증용:",mlp.score(X_test_scaled, y_test))
# Out:
# 학습용: 0.9943820224719101
# 검증용: 0.9943820224719101
# c:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
score_tr=mlp.score(X_train_scaled, y_train)
score_te=mlp.score(X_test_scaled, y_test)
print("학습용:",score_tr)
print("검증용:",score_te)
# Out:
# 학습용: 0.9943820224719101
# 검증용: 0.9943820224719101

# %%
result_tr.append(score_tr)
result_te.append(score_te)

# %% [markdown]
# ##### SVM

# %%
from sklearn.svm import SVC
svm = SVC(random_state=10)
svm.fit(X_train_scaled, y_train)
print("학습용:",svm.score(X_train_scaled, y_train))
print("검증용:",svm.score(X_test_scaled, y_test))
# Out:
# 학습용: 0.9873595505617978
# 검증용: 0.9887640449438202

# %%
#최적의 C value와 gamma value를 찾는 과정
import numpy as np
train_rate = []
test_rate = []
c_values = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
g_values = [0.0001, 0.001, 0.01, 0.1]
for n in c_values:
    for g in g_values:
        # 모델 생성
        svm = SVC(C=n,gamma=g,random_state=10)
        svm.fit(X_train_scaled, y_train)
        # 학습용 데이터셋의 정확도
        train_rate.append([n,g,svm.score(X_train_scaled, y_train)])
        # 검증용 데이터셋의 정확도
        test_rate.append([n,g,svm.score(X_test_scaled, y_test)])
        
train_arr=np.array(train_rate) #검증용 데이터셋의 정확도
test_arr=np.array(test_rate) #검증용 데이터셋의 정확도
max_rate=np.max(test_arr[:,2]) #가장 좋은 정확도
idx=np.argmax(test_arr[:,2]) #가장 성능이 좋은 인덱스
print("최적의 c:",test_rate[idx][0])
print("최적의 gamma:",test_rate[idx][1])
print("최고 정확도:",test_rate[idx][2])
# Out:
# 최적의 c: 100
# 최적의 gamma: 0.01
# 최고 정확도: 1.0

# %%
plt.rcParams["font.size"]=15
plt.plot(range(len(train_rate)), train_arr[:,2], label="학습용 데이터셋")
plt.plot(range(len(test_rate)), test_arr[:,2], label="검증용 데이터셋")
plt.ylabel("정확도")
plt.legend()

# %%
from sklearn.svm import SVC
svm = SVC(C=1,gamma=0.0001,random_state=10)
svm.fit(X_train_scaled, y_train)
score_tr=svm.score(X_train_scaled, y_train)
score_te=svm.score(X_test_scaled, y_test)
print("학습용:",score_tr)
print("검증용:",score_te)
# Out:
# 학습용: 0.9424157303370787
# 검증용: 0.9662921348314607

# %%
result_tr.append(score_tr)
result_te.append(score_te)

# %%
from keras.models import Sequential
from keras.layers import Dense
model = Sequential()
model.add(Dense(64,input_shape=(X.shape[1],),activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist = model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 23/23 [==============================] - 2s 4ms/step - loss: 0.4589 - accuracy: 0.8919
# Epoch 2/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2240 - accuracy: 0.9747
# Epoch 3/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1306 - accuracy: 0.9803
# Epoch 4/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0896 - accuracy: 0.9860
# Epoch 5/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0671 - accuracy: 0.9860
# Epoch 6/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9874
# Epoch 7/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 0.9902
# Epoch 8/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0398 - accuracy: 0.9874
# Epoch 9/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0354 - accuracy: 0.9902
# Epoch 10/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9916
# Epoch 11/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9930
# Epoch 12/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9930
# Epoch 13/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0254 - accuracy: 0.9930
# Epoch 14/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9930
# Epoch 15/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 0.9930
# Epoch 16/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9958
# Epoch 17/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9944
# Epoch 18/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9958
# Epoch 19/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9930
# Epoch 20/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9958
# Epoch 21/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9958
# Epoch 22/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9958
# Epoch 23/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9958
# Epoch 24/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9958
# Epoch 25/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9958
# Epoch 26/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9958
# Epoch 27/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9958
# Epoch 28/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9972
# Epoch 29/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9958
# Epoch 30/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 0.9972
# Epoch 31/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 32/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9972
# Epoch 33/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9972
# Epoch 34/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9972
# Epoch 35/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9986
# Epoch 36/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9972
# Epoch 37/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9986
# Epoch 38/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9986
# Epoch 39/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 40/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9972
# Epoch 41/100
# 23/23 [==============================] - 0s 12ms/step - loss: 0.0092 - accuracy: 0.9972
# Epoch 42/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 43/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 44/100
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 45/100
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 46/100
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0060 - accuracy: 0.9972
# Epoch 47/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 48/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9972
# Epoch 49/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9972
# Epoch 50/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 51/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 52/100
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 53/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 54/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9972
# Epoch 55/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 56/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 57/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 58/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 59/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 60/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 61/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 62/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 63/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 64/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 65/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 66/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 67/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 68/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 69/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 70/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 71/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 72/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 73/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 74/100
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 75/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 76/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9986
# Epoch 77/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9986
# Epoch 78/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 79/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.9986
# Epoch 80/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 81/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 82/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 83/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 84/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 85/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 86/100
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 0.9986
# Epoch 87/100
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 88/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 89/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 90/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 91/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 92/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 0.9986
# Epoch 93/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 94/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 95/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 96/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 97/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 98/100
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 99/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 100/100
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000

# %%
loss, acc_tr = model.evaluate(X_train_scaled, y_train, verbose=0)
loss, acc_te = model.evaluate(X_test_scaled, y_test, verbose=0)
print(acc_tr)
print(acc_te)
result_tr.append(acc_tr)
result_te.append(acc_te)
# Out:
# 1.0
# 1.0

# %% [markdown]
# ##### 확률적 경사하강법

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
model = Sequential()
model.add(Dense(64,input_shape=(X.shape[1],),activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
sgd = SGD(learning_rate=0.01)  
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 64)                576
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 4,801
# Trainable params: 4,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
es = EarlyStopping(monitor='val_loss', patience=5)
#                       종료기준          임계값
# 학습 과정에서 만들어진 최적의 파라미터 조합으로 모형을 저장
mc = ModelCheckpoint("school_best.h5", save_best_only=True)
#                       모형이름         최적의 모형만 선택
# 학습이 잘 안될 때 학습률을 동적으로 조절하는 옵션
rlr = ReduceLROnPlateau(factor=0.1, patience=5) #기존 학습률*factor (배수)
# 학습 과정의 주요 history를 csv로 저장
csvlogger = CSVLogger("mylog.csv")  
hist = model.fit(X_train_scaled, y_train, validation_split=0.2,
                 epochs=500, callbacks=[es, mc, rlr, csvlogger])
# Out:
# Epoch 1/500
# 18/18 [==============================] - 1s 17ms/step - loss: 0.6299 - accuracy: 0.7715 - val_loss: 0.6017 - val_accuracy: 0.8531 - lr: 0.0100
# Epoch 2/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5809 - accuracy: 0.8770 - val_loss: 0.5537 - val_accuracy: 0.9021 - lr: 0.0100
# Epoch 3/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5378 - accuracy: 0.9033 - val_loss: 0.5109 - val_accuracy: 0.9301 - lr: 0.0100
# Epoch 4/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4989 - accuracy: 0.9192 - val_loss: 0.4724 - val_accuracy: 0.9441 - lr: 0.0100
# Epoch 5/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4636 - accuracy: 0.9262 - val_loss: 0.4373 - val_accuracy: 0.9371 - lr: 0.0100
# Epoch 6/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4313 - accuracy: 0.9350 - val_loss: 0.4053 - val_accuracy: 0.9371 - lr: 0.0100
# Epoch 7/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4019 - accuracy: 0.9350 - val_loss: 0.3764 - val_accuracy: 0.9441 - lr: 0.0100
# Epoch 8/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.

# 18/18 [==============================] - 0s 10ms/step - loss: 0.0196 - accuracy: 0.9965 - val_loss: 0.0228 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 300/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.0227 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 301/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.0227 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 302/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0195 - accuracy: 0.9947 - val_loss: 0.0227 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 303/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0226 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 304/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0225 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 305/500
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.0225 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 306/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.9947 - val_loss: 0.0224 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 307/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9947 - val_loss: 0.0225 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 308/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.0225 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 309/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0191 - accuracy: 0.9947 - val_loss: 0.0224 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 310/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0224 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 311/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9947 - val_loss: 0.0223 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 312/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0223 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 313/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0222 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 314/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0221 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 315/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0221 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 316/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 0.9947 - val_loss: 0.0220 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 317/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9947 - val_loss: 0.0220 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 318/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 0.9947 - val_loss: 0.0220 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 319/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9947 - val_loss: 0.0220 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 320/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9947 - val_loss: 0.0219 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 321/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.0218 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 322/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.0218 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 323/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 0.9947 - val_loss: 0.0217 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 324/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0184 - accuracy: 0.9947 - val_loss: 0.0217 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 325/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9947 - val_loss: 0.0217 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 326/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 0.0217 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 327/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0183 - accuracy: 0.9947 - val_loss: 0.0216 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 328/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.0216 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 329/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.0215 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 330/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0215 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 331/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9965 - val_loss: 0.0215 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 332/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9947 - val_loss: 0.0215 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 333/500
# 18/18 [==============================] - 0s 9ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.0214 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 334/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 0.9947 - val_loss: 0.0214 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 335/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.0213 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 336/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.0213 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 337/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.0214 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 338/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0178 - accuracy: 0.9947 - val_loss: 0.0213 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 339/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.0213 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 340/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.0212 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 341/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0212 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 342/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0211 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 343/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0211 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 344/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0210 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 345/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0210 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 346/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 0.9947 - val_loss: 0.0210 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 347/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 348/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9965 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 349/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 350/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-03
# Epoch 351/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-03
# Epoch 352/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-03
# Epoch 353/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-03
# Epoch 354/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-03
# Epoch 355/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 356/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 357/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 358/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 359/500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 360/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 361/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 362/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 363/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 364/500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 365/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 366/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 367/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 368/500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-06
# Epoch 369/500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0209 - val_accuracy: 1.0000 - lr: 1.0000e-06

# %%
from keras.models import load_model
model=load_model('school_best.h5')  
model.evaluate(X_test_scaled, y_test, verbose=0)
# Out:
# [0.012769163586199284, 1.0]

# %% [markdown]
# ##### 알고리즘별 예측도 그래프

# %%
methods=["LOGIT","Tree","RF","KNN","ANN","SVM","DNN"]
result_tr_arr=np.array(result_tr) #검증용 데이터셋의 정확도
max_rate_tr=np.max(result_tr_arr) #가장 좋은 정확도
idx_tr=np.argmax(result_tr_arr) #가장 성능이 좋은 인덱스
result_te_arr=np.array(result_te) #검증용 데이터셋의 정확도
max_rate_te=np.max(result_te_arr) #가장 좋은 정확도
idx_te=np.argmax(result_te_arr) #가장 성능이 좋은 인덱스

print(methods)
print(result_tr)
print(result_te)
print("최적의 모형(학습용):",methods[idx_tr])
print("최고 정확도(학습용):",max_rate_tr)
print("최적의 모형(검증용):",methods[idx_te])
print("최고 정확도(검증용):",max_rate_te)

plt.rcParams["font.size"]=15
plt.plot(methods, result_tr_arr, label="학습용 정확도")
plt.plot(methods, result_te_arr, label="검증용 정확도")
plt.xlabel("분석방법")
plt.ylabel("정확도")
plt.legend()
# Out:
# ['LOGIT', 'Tree', 'RF', 'KNN', 'ANN', 'SVM', 'DNN']
# [0.9887640449438202, 0.9789325842696629, 1.0, 0.9803370786516854, 0.9943820224719101, 0.9424157303370787, 1.0]
# [0.9943820224719101, 0.9775280898876404, 0.9943820224719101, 0.9719101123595506, 0.9943820224719101, 0.9662921348314607, 1.0]
# 최적의 모형(학습용): RF
# 최고 정확도(학습용): 1.0
# 최적의 모형(검증용): DNN
# 최고 정확도(검증용): 1.0
