# %%
#산술 연산 : 덧셈, 알파 연산(가중치를 곱하는 방식), 뺄셈
import cv2
import matplotlib.pyplot as plt
img1 = cv2.imread("d:/data/images/apple_512.jpg")
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
img2 = cv2.imread('d:/data/images/peppers.png')
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(gray1,cmap='gray')
plt.axis("off")
plt.show()
plt.imshow(gray2,cmap='gray')
plt.axis("off")
plt.show()

# %%
gray1.shape, gray2.shape
# Out:
# ((512, 512), (512, 512))

# %%
height, width = gray1.shape
plus = gray1.copy()
minus = gray1.copy()
alpha = gray1.copy()
for i in range(height):
    for j in range(width):
        plus[i][j] = gray1[i][j] + gray2[i][j]
        minus[i][j] = gray1[i][j] - gray2[i][j]
        alpha[i][j] = gray1[i][j] * 0.7 + gray2[i][j] * (1 - 0.7)
    if plus[i][j] > 255:
        plus[i][j] = 255
    if minus[i][j] < 0:
        minus[i][j] = 0
    if alpha[i][j] > 255:
        alpha[i][j] = 255
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_16840\271562015.py:8: RuntimeWarning: overflow encountered in ubyte_scalars
#   minus[i][j] = gray1[i][j] - gray2[i][j]
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_16840\271562015.py:7: RuntimeWarning: overflow encountered in ubyte_scalars
#   plus[i][j] = gray1[i][j] + gray2[i][j]

# %%
plt.subplot(1, 5, 1)
plt.imshow(gray1,cmap='gray')
plt.axis("off")
plt.subplot(1, 5, 2)
plt.imshow(gray2,cmap='gray')
plt.axis("off")
plt.subplot(1, 5, 3)
plt.imshow(plus,cmap='gray')
plt.axis("off")
plt.subplot(1, 5, 4)
plt.imshow(minus,cmap='gray')
plt.axis("off")
plt.subplot(1, 5, 5)
plt.imshow(alpha,cmap='gray')
plt.axis("off")
plt.show()
# 덧셈, 뺄셈: 0, 255 값이 많이 나타남, 어떤 값을 더하고 뺐는지 명확하지 않음
# 알파 연산: 가중치가 큰 이미지는 선명하게 보이고 가중치가 작은 이미지는 약하게 보임(워터마크 처리 등에 유용함)
