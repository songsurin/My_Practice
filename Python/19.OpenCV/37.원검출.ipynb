# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("d:/data/images/colorball.jpg")
src = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(src)
plt.axis("off")
plt.show()

# %%
import cv2
dst = src.copy()
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
#cv2.HoughCircles(이미지, 검출 방법, 해상도 비율, 최소 거리, 캐니엣지 임계값, 중심 임계값, 최소 반지름, 최대 반지름)
circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, 1, 100,
                           param1 = 250, param2 = 10, 
                           minRadius = 80, maxRadius = 120)
for i in circles[0]:
    #원 그리기 함수
    cv2.circle(dst, (int(i[0]), int(i[1])), int(i[2]), (255, 255, 255), 5)

# %%
plt.imshow(dst)
plt.title('image1')
plt.axis("off")
plt.show()
